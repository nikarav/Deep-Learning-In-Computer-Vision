# %%
import numpy as np
from PIL import Image
import torch
from torchvision import transforms

# %% [markdown]
# # Load and display img with PIL

# %%
ls
# Out:
# ex_1_1.ipynb  img.png

# %%
# creating a object
img = Image.open(r"img.png")

display(img)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=657x566>

# %% [markdown]
# # Convert image to tensor, move to GPU, save the tensor and check if you used GPU correctly

# %%
# convert image to tensor
arr = np.array(img)
tensor = torch.from_numpy(arr)
# convert_tensor = transforms.ToTensor()
# convert_tensor(img)

# %%
tensor = tensor.to("cuda")

# %%
torch.save(tensor, "tensor.pt")

# %%
tensor.is_cuda
# Out:
# True
